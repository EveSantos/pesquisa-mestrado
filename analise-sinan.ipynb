# %% [markdown]
# ## Inicio do projeto
#
# Como os arquivos ja foram convertidos em csv, vou fazer a leitura de cada csv e separar os dados de Ilhéus e Itabuna

# %%
import pandas as pd

# %% [markdown]
# ### Ler e salvar dados de 2014 a 2019

# %%
# Ler dados de 2014 a 2019
deng_dados14 = pd.read_csv('./data/DENGBR14.csv')
deng_dados15 = pd.read_csv('./data/DENGBR15.csv')
deng_dados16 = pd.read_csv('./data/DENGBR16.csv')
deng_dados17 = pd.read_csv('./data/DENGBR17.csv')
deng_dados18 = pd.read_csv('./data/DENGBR18.csv')
deng_dados19 = pd.read_csv('./data/DENGBR19.csv')

# %%
# Ler apenas os dados de ilhéus e itabuna do ano de 2014 a 19
codigo_ilheus_itabna = [291360,291480]

deng_dados14_ba = deng_dados14[deng_dados14['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados15_ba = deng_dados15[deng_dados15['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados16_ba = deng_dados16[deng_dados16['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados17_ba = deng_dados17[deng_dados17['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados18_ba = deng_dados18[deng_dados18['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados19_ba = deng_dados19[deng_dados19['ID_MUNICIP'].isin(codigo_ilheus_itabna)]

# %%
# Salvar novos csvs de 14 a 19
deng_dados14_ba.to_csv('data-filtred/deng_dados14_ba.csv', index=False)
deng_dados15_ba.to_csv('data-filtred/deng_dados15_ba.csv', index=False)
deng_dados16_ba.to_csv('data-filtred/deng_dados16_ba.csv', index=False)
deng_dados17_ba.to_csv('data-filtred/deng_dados17_ba.csv', index=False)
deng_dados18_ba.to_csv('data-filtred/deng_dados18_ba.csv', index=False)
deng_dados19_ba.to_csv('data-filtred/deng_dados19_ba.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Salvar novos csvs de 14 a 19
# ----> 2 deng_dados14_ba.to_csv('data-filtred/deng_dados14_ba.csv', index=False)
#       3 deng_dados15_ba.to_csv('data-filtred/deng_dados15_ba.csv', index=False)
#       4 deng_dados16_ba.to_csv('data-filtred/deng_dados16_ba.csv', index=False)
#
# NameError: name 'deng_dados14_ba' is not defined

# %% [markdown]
# ### Ler dados de 2020 a 2022

# %%
deng_dados20 = pd.read_csv('./data/DENGBR20.csv')
deng_dados21 = pd.read_csv('./data/DENGBR21.csv')
deng_dados22 = pd.read_csv('./data/DENGBR22.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 deng_dados20 = pd.read_csv('./data/DENGBR20.csv')
#       2 deng_dados21 = pd.read_csv('./data/DENGBR21.csv')
#       3 deng_dados22 = pd.read_csv('./data/DENGBR22.csv')
#
# ...

# %%
# Ler apenas os dados de ilhéus e itabuna do ano de 2020 a 22
codigo_ilheus_itabna = [291360,291480]

deng_dados20_ba = deng_dados20[deng_dados20['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados21_ba = deng_dados21[deng_dados21['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados22_ba = deng_dados22[deng_dados22['ID_MUNICIP'].isin(codigo_ilheus_itabna)]

# %%
# Salvar novos csvs de 14 a 19
deng_dados20_ba.to_csv('data-filtred/deng_dados20_ba.csv', index=False)
deng_dados21_ba.to_csv('data-filtred/deng_dados21_ba.csv', index=False)
deng_dados22_ba.to_csv('data-filtred/deng_dados22_ba.csv', index=False)

# %% [markdown]
# ### Ler dados de 2023

# %%
# Ler apenas os dados de ilhéus e itabuna do ano de 2023
codigo_ilheus_itabna = [291360,291480]
deng_dados23 = pd.read_csv('./data/DENGBR23.csv')

deng_dados23_ba = deng_dados23[deng_dados23['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados23_ba.to_csv('data-filtred/deng_dados23_ba.csv', index=False)
# Out:
# /tmp/ipykernel_49186/3690604613.py:3: DtypeWarning: Columns (21,22,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   deng_dados23 = pd.read_csv('./data/DENGBR23.csv')

# %%
deng_dados22_ba.head()
# Out:
#        TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 42920       2       A90    20221222   202251    2022         29      291480
# 42921       2       A90    20220420   202216    2022         29      291480
# 42922       2       A90    20220420   202216    2022         29      291480
# 42933       2       A90    20220714   202228    2022         29      291480
# 43335       2       A90    20221213   202250    2022         29      291480
#
#        ID_REGIONA  ID_UNIDADE DT_SIN_PRI  ...  EVIDENCIA  PLAQ_MENOR  CON_FHD  \
# 42920      1385.0   2470330.0   20221211  ...        NaN         NaN      NaN
# 42921      1385.0   2525569.0   20220415  ...        NaN         NaN      NaN
# 42922      1385.0   2525569.0   20220415  ...        NaN         NaN      NaN
# 42933      1385.0   2385171.0   20220707  ...        NaN         NaN      NaN
# 43335      1385.0   2470330.0   20221119  ...        NaN         NaN      NaN
#
# ...

# %% [markdown]
# ### Ler dados de 2023
#
# Como os dados de 2024 são muito grandes, foi necessario fazer a leitura por chunks, facilitando e consumindo menos memoria

# %%
chunks = pd.read_csv('./data/DENGBR24.csv', chunksize=100000, low_memory=False)
deng_dados24 = pd.concat(chunks)

# %%
deng_dados24_ba = deng_dados24[deng_dados24['ID_MUNICIP'].isin(codigo_ilheus_itabna)]

# %%
deng_dados24_ba.to_csv('data-filtred/deng_dados24_ba.csv', index=False)

# %% [markdown]
# ### Dados
#
# Algumas analises dos dados e do tipo de informacão contida nos dataframes

# %%
pd

# %%
deng_dados24_ba.ID_MUNICIP.value_counts()
# Out:
# ID_MUNICIP
# 291360    3290
# 291480     645
# Name: count, dtype: int64

# %%
print(deng_dados24_ba.columns)
# Out:
# Index(['TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'SG_UF_NOT',
#        'ID_MUNICIP', 'ID_REGIONA', 'ID_UNIDADE', 'DT_SIN_PRI',
#        ...
#        'EVIDENCIA', 'PLAQ_MENOR', 'CON_FHD', 'COMPLICA', 'TP_SISTEMA',
#        'NDUPLIC_N', 'DT_DIGITA', 'CS_FLXRET', 'FLXRECEBI', 'MIGRADO_W'],
#       dtype='object', length=121)

# %%
deng_dados24_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3935 entries, 11036 to 6363994
# Columns: 121 entries, TP_NOT to MIGRADO_W
# dtypes: float64(94), int64(10), object(17)
# memory usage: 3.7+ MB

# %%
deng_dados24_ba.RESUL_SORO.value_counts()
# Out:
# RESUL_SORO
# 4.0    460
# 1.0    144
# 2.0      8
# 3.0      2
# Name: count, dtype: int64

# %%
deng_dados24_ba.EVOLUCAO.value_counts()
# Out:
# EVOLUCAO
# 1.0    2149
# 9.0      12
# 3.0       4
# 2.0       1
# Name: count, dtype: int64

# %%
pd.concat([ deng_dados14, deng_dados23])
# Out:
#          TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0             2       A90  2014-05-17   201420    2014         12      120040
# 1             2       A90  2014-07-09   201428    2014         12      120040
# 2             2       A90  2014-09-03   201436    2014         12      120020
# 3             2       A90  2014-10-13   201442    2014         12      120020
# 4             2       A90  2014-03-28   201413    2014         12      120040
# ...         ...       ...         ...      ...     ...        ...         ...
# 1508648       2       A90    20231228   202352    2023         17      172120
# 1508649       2       A90    20231229   202352    2023         17      170700
# 1508650       2       A90    20231229   202352    2023         17      170820
# 1508651       2       A90    20231229   202352    2023         17      170700
# 1508652       2       A90    20231229   202352    2023         17      172100
#
# ...

# %%
from pysus import SINAN
sinan = SINAN().load() # Loads the files from DATASUS

# %%
codigo_ilheus_itabna = [291480,291360]
deng_dados14_ba = deng_dados14[deng_dados14['ID_MUNICIP'].isin(codigo_ilheus_itabna)]
deng_dados14_ba
# Out:
#        TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 67512       2       A90  2014-07-07   201428    2014         29      291480
# 67516       2       A90  2014-07-14   201429    2014         29      291480
# 67517       2       A90  2014-04-23   201417    2014         29      291480
# 67518       2       A90  2014-01-24   201404    2014         29      291480
# 67519       2       A90  2014-01-24   201404    2014         29      291480
# ...       ...       ...         ...      ...     ...        ...         ...
# 92126       2       A90  2014-03-24   201413    2014         29      291480
# 92138       2       A90  2014-03-31   201414    2014         29      291480
# 92147       2       A90  2014-03-07   201410    2014         29      291360
# 92172       2       A90  2014-03-20   201412    2014         29      291360
# 92226       2       A90  2014-03-18   201412    2014         29      291480
#
# ...

# %%
# deng_dados23.NU_IDADE_N.value_counts()
# for cname in deng_dados23.columns:
#     if cname.startswith('DT_'):
#         deng_dados23[cname] = pd.to_datetime(deng_dados23[cname], errors='coerce')
#     elif cname.startswith('ID_'):
#         try:
#             deng_dados23[cname] = pd.to_numeric(deng_dados23[cname])
#         except ValueError:
#             continue
# deng_dados23.info()

# %% [markdown]
# ### Leitura da base de dados filtrada

# %% [markdown]
# Leitura dados 2014

# %%
deng_2014 = pd.read_csv('./data-filtred/deng_dados14_ba.csv')
deng_2014
# Out:
#       TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0          2       A90  2014-07-07   201428    2014         29      291480
# 1          2       A90  2014-07-14   201429    2014         29      291480
# 2          2       A90  2014-04-23   201417    2014         29      291480
# 3          2       A90  2014-01-24   201404    2014         29      291480
# 4          2       A90  2014-01-24   201404    2014         29      291480
# ...      ...       ...         ...      ...     ...        ...         ...
# 2141       2       A90  2014-03-24   201413    2014         29      291480
# 2142       2       A90  2014-03-31   201414    2014         29      291480
# 2143       2       A90  2014-03-07   201410    2014         29      291360
# 2144       2       A90  2014-03-20   201412    2014         29      291360
# 2145       2       A90  2014-03-18   201412    2014         29      291480
#
# ...

# %%
deng_2014.NU_IDADE_N.value_counts()
# Out:
# NU_IDADE_N
# 4020.0    66
# 4026.0    62
# 4027.0    61
# 4021.0    60
# 4033.0    59
#           ..
# 3009.0     1
# 4081.0     1
# 3005.0     1
# 4089.0     1
# 4084.0     1
# Name: count, Length: 100, dtype: int64

# %%
for cname in deng_2014.columns:
    if cname.startswith('DT_'):
        deng_2014[cname] = pd.to_datetime(deng_2014[cname], errors='coerce')
    elif cname.startswith('ID_'):
        try:
            deng_2014[cname] = pd.to_numeric(deng_2014[cname])
        except ValueError:
            continue

# %%
from pysus.preprocessing.decoders import decodifica_idade_SINAN

# %%
deng_2014['idade_anos'] = decodifica_idade_SINAN(
    deng_2014['NU_IDADE_N'],
    unidade='Y'
)

# %%
deng_2014
# Out:
#       TP_NOT ID_AGRAVO DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0          2       A90 2014-07-07   201428    2014         29      291480
# 1          2       A90 2014-07-14   201429    2014         29      291480
# 2          2       A90 2014-04-23   201417    2014         29      291480
# 3          2       A90 2014-01-24   201404    2014         29      291480
# 4          2       A90 2014-01-24   201404    2014         29      291480
# ...      ...       ...        ...      ...     ...        ...         ...
# 2141       2       A90 2014-03-24   201413    2014         29      291480
# 2142       2       A90 2014-03-31   201414    2014         29      291480
# 2143       2       A90 2014-03-07   201410    2014         29      291360
# 2144       2       A90 2014-03-20   201412    2014         29      291360
# 2145       2       A90 2014-03-18   201412    2014         29      291480
#
#       ID_REGIONA  ID_UNIDADE DT_SIN_PRI  ...  PLASMATICO EVIDENCIA  \
# ...

# %%
import glob

path = './data-filtred/*.csv'

arquivos = glob.glob(path)

lista_dfs = [pd.read_csv(arq) for arq in arquivos]
df_deng_total = pd.concat(lista_dfs, ignore_index=True)
# Out:
# /tmp/ipykernel_12538/965835360.py:7: DtypeWarning: Columns (9,21,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_dfs = [pd.read_csv(arq) for arq in arquivos]
# /tmp/ipykernel_12538/965835360.py:7: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_dfs = [pd.read_csv(arq) for arq in arquivos]

# %%
df_deng_total.NU_IDADE_N.value_counts()
# Out:
# NU_IDADE_N
# 4022.0    313
# 4024.0    297
# 4023.0    297
# 4021.0    296
# 4027.0    286
#          ...
# 18.0        1
# 2009.0      1
# 2024.0      1
# 37.0        1
# 2019.0      1
# Name: count, Length: 130, dtype: int64

# %%
df_deng_total['idade_anos'] = None

mask = df_deng_total['NU_IDADE_N'].notna()

df_deng_total.loc[mask, 'idade_anos'] = decodifica_idade_SINAN(
    df_deng_total.loc[mask, 'NU_IDADE_N'],
    unidade='Y'
)
df_deng_total.idade_anos.value_counts()
# Out:
# idade_anos
# 22.000000    313
# 24.000000    297
# 23.000000    297
# 21.000000    296
# 27.000000    286
#             ...
# 0.027397       1
# 0.115068       1
# 0.024658       1
# 0.065753       1
# 0.052055       1
# Name: count, Length: 125, dtype: int64
